# %%
import spacy
from spacy import displacy

nlp = spacy.load("en_core_web_sm")

piano_class_text = (
    "The future of India will be shaped by today’s younger generation who need quality education through digital literacy, making them productive and self-reliant citizens."
    "'Digital literacy' is the skills required to achieve digital competence and use of Information and Communication Technology (ICT) for work, leisure, learning and communication."
    "It does not replace traditional forms of literacy, instead complements and amplifies the skills that form the foundation of traditional forms."
    "Learners can benefit from the knowledgebase and experience of 4 decades of Infosys as an enterprise."
    "We also bring the quality content from our partners and leading universities across the world."
    "Content is aligned with New Education policy 2020." 
    " In Mayfair or the City of London and has"
    " world-class piano instructors."
    "Includes soft skills and vocational skills."
    "Infosys Springboard is a Digital literacy program launched as part of the Infosys ESG Tech for Good charter." 
    "It aims to enable students and associated communities from early education to lifelong learners by imparting digital"
    "life skills through curated content & interventions, free of cost."
    
)
piano_class_doc = nlp(piano_class_text)

# Show visualization in browser
displacy.serve(piano_class_doc, style="ent", auto_select_port=True)


# Print entity details
for ent in piano_class_doc.ents:
    print(
        f"""
{ent.text = }
{ent.start_char = }
{ent.end_char = }
{ent.label_ = }
spacy.explain('{ent.label_}') = {spacy.explain(ent.label_)}"""
    )
# Out:
# C:\Users\Admin\AppData\Roaming\Python\Python312\site-packages\spacy\util.py:1846: UserWarning: [W124] 0.0.0.0:5000 is already in use, using the nearest available port 5001 as an alternative.
#   warnings.warn(Warnings.W124.format(host=host, port=start, serve_port=port))
# C:\Users\Admin\AppData\Roaming\Python\Python312\site-packages\spacy\displacy\__init__.py:106: UserWarning: [W011] It looks like you're calling displacy.serve from within a Jupyter notebook or a similar environment. This likely means you're already running a local web server, so there's no need to make displaCy start another one. Instead, you should be able to replace displacy.serve with displacy.render to show the visualization.
#   warnings.warn(Warnings.W011)
# <span class="tex2jax_ignore"><!DOCTYPE html>
# <html lang="en">
#     <head>
#         <title>displaCy</title>
#     </head>
#
#     <body style="font-size: 16px; font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Helvetica, Arial, sans-serif, 'Apple Color Emoji', 'Segoe UI Emoji', 'Segoe UI Symbol'; padding: 4rem 2rem; direction: ltr">
# <figure style="margin-bottom: 6rem">
# <div class="entities" style="line-height: 2.5; direction: ltr">The future of
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     India
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  will be shaped by
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     today
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# ’s younger generation who need quality education through digital literacy, making them productive and self-reliant citizens.'Digital literacy' is the skills required to achieve digital competence and use of
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Information and Communication Technology
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  (
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ICT
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ) for work, leisure, learning and communication.It does not replace traditional forms of literacy, instead complements and amplifies the skills that form the foundation of traditional forms.Learners can benefit from the knowledgebase and experience of
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     4 decades
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  of
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Infosys
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  as an enterprise.We also bring the quality content from our partners and leading universities across the world.
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Content
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  is aligned with
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     New Education
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  policy
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2020
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# . In
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Mayfair
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  or
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the City of London
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  and has world-class piano instructors.Includes soft skills and vocational skills.
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Infosys Springboard
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  is a
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Digital
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  literacy program launched as part of
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the Infosys ESG Tech
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  for Good charter.It aims to enable students and associated communities from early education to lifelong learners by imparting digitallife skills through curated content &amp; interventions, free of cost.</div>
# </figure>
# </body>
# </html></span>
# Using the 'ent' visualizer
# Serving on http://0.0.0.0:5001 ...
#
# Shutting down server on port 5001.
#
# ent.text = 'India'
# ent.start_char = 14
# ent.end_char = 19
# ent.label_ = 'GPE'
# spacy.explain('GPE') = Countries, cities, states
#
# ent.text = 'today'
# ent.start_char = 38
# ent.end_char = 43
# ent.label_ = 'DATE'
# spacy.explain('DATE') = Absolute or relative dates or periods
#
# ent.text = 'Information and Communication Technology'
# ent.start_char = 250
# ent.end_char = 290
# ent.label_ = 'ORG'
# spacy.explain('ORG') = Companies, agencies, institutions, etc.
#
# ent.text = 'ICT'
# ent.start_char = 292
# ent.end_char = 295
# ent.label_ = 'ORG'
# spacy.explain('ORG') = Companies, agencies, institutions, etc.
#
# ent.text = '4 decades'
# ent.start_char = 547
# ent.end_char = 556
# ent.label_ = 'DATE'
# spacy.explain('DATE') = Absolute or relative dates or periods
#
# ent.text = 'Infosys'
# ent.start_char = 560
# ent.end_char = 567
# ent.label_ = 'ORG'
# spacy.explain('ORG') = Companies, agencies, institutions, etc.
#
# ent.text = 'Content'
# ent.start_char = 679
# ent.end_char = 686
# ent.label_ = 'ORG'
# spacy.explain('ORG') = Companies, agencies, institutions, etc.
#
# ent.text = 'New Education'
# ent.start_char = 703
# ent.end_char = 716
# ent.label_ = 'ORG'
# spacy.explain('ORG') = Companies, agencies, institutions, etc.
#
# ent.text = '2020'
# ent.start_char = 724
# ent.end_char = 728
# ent.label_ = 'DATE'
# spacy.explain('DATE') = Absolute or relative dates or periods
#
# ent.text = 'Mayfair'
# ent.start_char = 733
# ent.end_char = 740
# ent.label_ = 'PERSON'
# spacy.explain('PERSON') = People, including fictional
#
# ent.text = 'the City of London'
# ent.start_char = 744
# ent.end_char = 762
# ent.label_ = 'GPE'
# spacy.explain('GPE') = Countries, cities, states
#
# ent.text = 'Infosys Springboard'
# ent.start_char = 844
# ent.end_char = 863
# ent.label_ = 'PERSON'
# spacy.explain('PERSON') = People, including fictional
#
# ent.text = 'Digital'
# ent.start_char = 869
# ent.end_char = 876
# ent.label_ = 'ORG'
# spacy.explain('ORG') = Companies, agencies, institutions, etc.
#
# ent.text = 'the Infosys ESG Tech'
# ent.start_char = 914
# ent.end_char = 934
# ent.label_ = 'ORG'
# spacy.explain('ORG') = Companies, agencies, institutions, etc.
